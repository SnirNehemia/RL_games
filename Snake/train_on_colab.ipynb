# %%
import sys
from google.colab import drive

# 1. Mount the drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# 2. Add your repository folder to the Python path
# Replace 'YourRepoName' with the actual folder name in your Drive
repo_path = '/content/drive/MyDrive/Snake'
if repo_path not in sys.path:
    sys.path.append(repo_path)

import os

# Use the same repo_path we defined earlier
os.chdir(repo_path)

# Verify we are in the right place
print("Current Directory:", os.getcwd())
# Out:
# Mounted at /content/drive
# Current Directory: /content/drive/Othercomputers/My laptop/Snake

# %%
import importlib
import train

# Force Python to re-read the train.py file and its internal config loading
importlib.reload(train)
train.train()
# Out:
# training version: 1.0.1
# Using device: cuda
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10510/1870677053.py in <cell line: 0>()
#       4 # Force Python to re-read the train.py file and its internal config loading
#       5 importlib.reload(train)
# ----> 6 train.train()
#
# /content/drive/Othercomputers/My laptop/Snake/train.py in train()
#     179                 raise ValueError(f"CNN network type is not supported for state_type '{config.run_parameters.state_type}'")
#     180
# --> 181             agent = brain.actor_cnn(input_size=input_size, output_size=3, mlp_head_size=config.network_parameters.mlp_head_size,
#     182                                     kernel_sizes=config.network_parameters.kernel_sizes, cnn_filters=config.network_parameters.cnn_filters,
#     183                                     seed=config.seed, state_shape=state_shape)
#
# TypeError: actor_cnn.__init__() got an unexpected keyword argument 'mlp_head_size'
